# %%
# Dependencies
import pandas as pd

# %%
# List of file names to be combined 
files21 = ['citbike\JC-202101-citibike-tripdata.csv']

# Create an empty list to store each dataframe
df21_list = []

# Loop through each file in the list
for file in files21:
    # Read the file into a dataframe
    df21 = pd.read_csv(file)

    # Append the dataframe to the list
    df21_list.append(df21)

# Concatenate all dataframes in the list into one dataframe
df21 = pd.concat(df21_list)

# Show dataframe
df21
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1              1543  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2              1461  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3               793  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4               596  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
# ...             ...                       ...                       ...
# 11619          2476  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 11620           147  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 11621           660  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 11622           384  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 11623           356  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        start station id start station name  start station latitude  \
# ...

# %%
# List of file names to be combined 
files22 = ['citbike\JC-202102-citibike-tripdata.csv']

# Create an empty list to store each dataframe
df22_list = []

# Loop through each file in the list
for f in files22:
    # Read the file into a dataframe
    df22 = pd.read_csv(f)

    # Append the dataframe to the list
    df22_list.append(df22)

# Concatenate all dataframes in the list into one DataFrame
df22 = pd.concat(df22_list)

# Show dataframe
df22
# Out:
#                ride_id rideable_type           started_at  \
# 0     121DD7DD23CB1335   docked_bike  2021-02-03 23:11:28
# 1     FD73FB85F008349D   docked_bike  2021-02-27 16:34:05
# 2     39F9E6663CB5FDF6   docked_bike  2021-02-26 23:16:04
# 3     A64745CB0792EC6F   docked_bike  2021-02-24 16:51:50
# 4     75CC76EB9543764A   docked_bike  2021-02-24 20:44:16
# ...                ...           ...                  ...
# 4876  3F8FD9A051C0E3DA   docked_bike  2021-02-24 18:05:45
# 4877  B91F3593C0C06D04   docked_bike  2021-02-22 18:22:04
# 4878  A790954A017D07CB   docked_bike  2021-02-13 12:21:49
# 4879  42B1932D06CEE034   docked_bike  2021-02-25 11:20:29
# 4880  F71732ECE7CD02CF   docked_bike  2021-02-19 13:59:22
#
#                  ended_at          start_station_name start_station_id  \
# 0     2021-02-03 23:18:28  Hoboken Ave at Monmouth St            JC105
# 1     2021-02-27 16:56:40                Newport Pkwy            JC008
# ...

# %%
# Concatenate all dataframes for all the years into one
combined_df = pd.concat([df21, df22,], axis=0)

# Display the results
combined_df
# Out:
#       tripduration                 starttime                  stoptime  \
# 0            266.0  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1           1543.0  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2           1461.0  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3            793.0  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4            596.0  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
# ...            ...                       ...                       ...
# 4876           NaN                       NaN                       NaN
# 4877           NaN                       NaN                       NaN
# 4878           NaN                       NaN                       NaN
# 4879           NaN                       NaN                       NaN
# 4880           NaN                       NaN                       NaN
#
#       start station id start station name  start station latitude  \
# ...

# %%
# Dictionary mapping values in the 'gender' column to new values
mapping = {0: 'Unknown', 1: 'Male', 2: 'Female'}

# Use the 'map' method to change the values in the 'gender' column
combined_df['gender'] = combined_df['gender'].map(mapping)

# Show DataFrame
combined_df
# Out:
#       tripduration                 starttime                  stoptime  \
# 0            266.0  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1           1543.0  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2           1461.0  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3            793.0  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4            596.0  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
# ...            ...                       ...                       ...
# 4876           NaN                       NaN                       NaN
# 4877           NaN                       NaN                       NaN
# 4878           NaN                       NaN                       NaN
# 4879           NaN                       NaN                       NaN
# 4880           NaN                       NaN                       NaN
#
#       start station id start station name  start station latitude  \
# ...

# %%
# Save the dataframe to a CSV file
combined_df.to_csv('datecitibike.csv', index=False)
